# %%
import pandas as pd

d = pd.read_csv("https://raw.githubusercontent.com/nethajinirmal13/Training-datasets/main/titanic_train.csv")

# %%
d
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pd.pivot_table(d,index=['Sex'])
# Out:
#               Age       Fare     Parch  PassengerId    Pclass     SibSp  \
# Sex
# female  27.915709  44.479818  0.649682   431.028662  2.159236  0.694268
# male    30.726645  25.523893  0.235702   454.147314  2.389948  0.429809
#
#         Survived
# Sex
# female  0.742038
# male    0.188908

# %%
pd.pivot_table(d,index=['Pclass'])
# Out:
#               Age       Fare     Parch  PassengerId     SibSp  Survived
# Pclass
# 1       38.233441  84.154687  0.356481   461.597222  0.416667  0.629630
# 2       29.877630  20.662183  0.380435   445.956522  0.402174  0.472826
# 3       25.140620  13.675550  0.393075   439.154786  0.615071  0.242363

# %%
pd.pivot_table(d,index=['Sex','Pclass'])
# Out:
#                      Age        Fare     Parch  PassengerId     SibSp  \
# Sex    Pclass
# female 1       34.611765  106.125798  0.457447   469.212766  0.553191
#        2       28.722973   21.970121  0.605263   443.105263  0.486842
#        3       21.750000   16.118810  0.798611   399.729167  0.895833
# male   1       41.281386   67.226127  0.278689   455.729508  0.311475
#        2       30.740707   19.741782  0.222222   447.962963  0.342593
#        3       26.507589   12.661633  0.224784   455.515850  0.498559
#
#                Survived
# Sex    Pclass
# female 1       0.968085
#        2       0.921053
#        3       0.500000
# male   1       0.368852
#        2       0.157407
#        3       0.135447

# %%
pd.pivot_table(d,index=['Sex','Pclass'],aggfunc=['count'])

#min,max,Average or Mean.....
# Out:
#               count                                                            \
#                 Age Cabin Embarked Fare Name Parch PassengerId SibSp Survived
# Sex    Pclass
# female 1         85    81       92   94   94    94          94    94       94
#        2         74    10       76   76   76    76          76    76       76
#        3        102     6      144  144  144   144         144   144      144
# male   1        101    95      122  122  122   122         122   122      122
#        2         99     6      108  108  108   108         108   108      108
#        3        253     6      347  347  347   347         347   347      347
#
#
#               Ticket
# Sex    Pclass
# female 1          94
#        2          76
#        3         144
# male   1         122
#        2         108
#        3         347

# %%
pd.pivot_table(d,index=['Sex','Pclass'],values=['Age','Survived'])
# Out:
#                      Age  Survived
# Sex    Pclass
# female 1       34.611765  0.968085
#        2       28.722973  0.921053
#        3       21.750000  0.500000
# male   1       41.281386  0.368852
#        2       30.740707  0.157407
#        3       26.507589  0.135447
