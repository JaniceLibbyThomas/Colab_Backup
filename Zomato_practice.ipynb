# %%
# https://raw.githubusercontent.com/nethajinirmal13/Training-datasets/main/zomato/zomato.csv

import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/JaniceLibbyThomas/Sample_Dataset/main/Zomato.csv')
# df.to_csv('zomato.csv')
df.head(10)

df1 = pd.read_csv('https://raw.githubusercontent.com/JaniceLibbyThomas/Sample_Dataset/main/Country-Code.csv')
df1

# df2 = pd.read_csv('https://raw.githubusercontent.com/JaniceLibbyThomas/Sample_Dataset/main/Country-Code.csv')
# df2
# Out:
#     Country Code         Country Currency_code
# 0              1           India           INR
# 1             14       Australia           AUD
# 2             30          Brazil           BRL
# 3             37          Canada           CAD
# 4             94       Indonesia           IDR
# 5            148     New Zealand           NZD
# 6            162     Phillipines           PHP
# 7            166           Qatar           QAR
# 8            184       Singapore           SGD
# 9            189    South Africa           ZAR
# 10           191       Sri Lanka           LKR
# 11           208          Turkey           TRY
# 12           214             UAE           QAR
# 13           215  United Kingdom           GBP
# 14           216   United States           USD

# %%
#checking for the missing value

df.isna().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average_Cost_for_two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %% [markdown]
# **Finding the Exchange Rate**

# %%
from easy_exchange_rates import API
api = API()
currency_conversion = list(df1['Currency_code'])
print(currency_conversion)
indian_exchange_rate =[]

for i in range (0,len(currency_conversion)):
  time_series = api.get_exchange_rates(
  base_currency=currency_conversion[i], 
  start_date=str(date.today()), 
  end_date=str(date.today()), 
  targets=["INR"]
)
  data_frame = api.to_dataframe(time_series)
  indian_exchange_rate.append((time_series[str(date.today())]['INR']))
# print(data_frame.head(5))
# print(indian_exchange_rate)
df1['indian_exchange_rate']=indian_exchange_rate
df1
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-ca320306a4fe> in <module>
# ----> 1 from easy_exchange_rates import API
#       2 api = API()
#       3 currency_conversion = list(df1['Currency_code'])
#       4 print(currency_conversion)
#       5 indian_exchange_rate =[]
#
# ModuleNotFoundError: No module named 'easy_exchange_rates'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# creating a new column for country based on country code

# saved the dataframe as df2 after merging with the country code.

df3 = pd.merge(df, df1)
df3
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml郾 Gurme           208          哿stanbul
# 9547        5908749               Ceviz A埕ac郾           208          哿stanbul
# 9548        5915807                     Huqqa           208          哿stanbul
# 9549        5916112                A侓侓k Kahve           208          哿stanbul
# 9550        5927402  Walter's Coffee Roastery           208          哿stanbul
#
# ...

# %% [markdown]
# **converting all the price to INR**

# %%
ex_rate = list(df3['indian_exchange_rate'])
# print(ex_rate)

rate_conversion = list(df3['Average_Cost_for_two'])
# print(rate_conversion)

Price_in_INR = []
for i in range (0,len(rate_conversion)):
  Price_in_INR.append(ex_rate[i]*rate_conversion[i])

df3['Indian_Rupee']=Price_in_INR
df3
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml郾 Gurme           208          哿stanbul
# 9547        5908749               Ceviz A埕ac郾           208          哿stanbul
# 9548        5915807                     Huqqa           208          哿stanbul
# 9549        5916112                A侓侓k Kahve           208          哿stanbul
# 9550        5927402  Walter's Coffee Roastery           208          哿stanbul
#
# ...

# %%
# print(df4.columns)
print(df3.columns)
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average_Cost_for_two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country', 'Currency_code', 'indian_exchange_rate',
#        'Indian_Rupee'],
#       dtype='object')

# %% [markdown]
# #case2

# %%
# !pip install jupyter_dash
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 65.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 68.7 MB/s eta 0:00:00
# ...

# %%
from jupyter_dash import JupyterDash
import dash_core_components as dcc
import dash_html_components as html
 
 
app = JupyterDash(__name__)
 
app.layout = html.Div([
   html.Div(children=[
       html.Label('Dropdown'),
       dcc.Dropdown(
       dcc.Dropdown(df1.columns, id='pandas-dropdown-1'),
       html.Div(id='pandas-output-container-1')       
       ),     
   ]) 
 
])
 
if __name__ == '__main__':
   app.run_server(debug=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-3f49730c96aa> in <module>
#      10        html.Label('Dropdown'),
#      11        dcc.Dropdown(
# ---> 12        dcc.Dropdown(df1.columns, id='pandas-dropdown-1'),
#      13        html.Div(id='pandas-output-container-1')
#      14        ),
#
# NameError: name 'df1' is not defined

# %%
from dash import Dash, dcc, html, Input, Output
from plotly.express import data
import pandas as pd

df =  data.medals_long()

app = Dash(__name__)
app.layout = html.Div([
    dcc.Dropdown(df.columns, id='pandas-dropdown-1'),
    html.Div(id='pandas-output-container-1')
])


@app.callback(
    Output('pandas-output-container-1', 'children'),
    Input('pandas-dropdown-1', 'value')
)
def update_output(value):
    return f'You have selected {value}'


if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-8-768ba5f4e8d5> in <module>
#      21
#      22 if __name__ == '__main__':
# ---> 23     app.run_server(debug=True)
#
# /usr/local/lib/python3.8/dist-packages/dash/dash.py in run_server(self, *args, **kwargs)
#    2131         See `app.run` for usage information.
#    2132         """
# -> 2133         self.run(*args, **kwargs)
#
# /usr/local/lib/python3.8/dist-packages/dash/dash.py in run(self, host, port, proxy, debug, dev_tools_ui, dev_tools_props_check, dev_tools_serve_dev_bundles, dev_tools_hot_reload, dev_tools_hot_reload_interval, dev_tools_hot_reload_watch_interval, dev_tools_hot_reload_max_retry, dev_tools_silence_routes_logging, dev_tools_prune_errors, **flask_run_options)
#    1978                     extra_files.append(path)
#    1979
# ...

# %% [markdown]
# #currency conversion - draft

# %%
# !pip install CurrencyConverter
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 562.3/562.3 KB 20.4 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
from forex_python.converter import CurrencyRates
# from datetime import date
from currency_converter import CurrencyConverter

# c = CurrencyRates()

c = CurrencyConverter()

currency_conversion = list(df3['Currency_code'])
print(currency_conversion)

rate_conversion = list(df3['Average_Cost_for_two'])
print(rate_conversion)

Indian_Rupee = []

for i in range (0,len(currency_conversion)):

  url = "https://api.apilayer.com/fixer/convert?to=" + 'INR' + "&from=" + currency_conversion[i] + "&amount=" + str(rate_conversion[i])

  payload = {}
  headers= {
  "apikey": "RJXDDxEBBiBemQohGYhnS9mg6tKBWqUb"
  }

  response = requests.request("GET", url, headers = headers, data = payload)

  status_code = response.status_code

  result = response.json()

  print(result)
  res = str(result["result"])
  Indian_Rupee.append(res)

print(Indian_Rupee)
# df3['Indian_Rupee'] = df3.apply( lambda x: c.convert( x.Currency_code ,'INR', x.Average_Cost_for_two,date.today()), axis = 1)

# %%
from forex_python.converter import CurrencyRates
import datetime

c = CurrencyRates()
dt = date.today()
currency_conversion = list(df1['Currency_code'])
print(currency_conversion)

rate_conversion = list(df3['Average_Cost_for_two'])
print(rate_conversion)

currency_rate=[]
for i in range (0,len(currency_conversion)):
  currency_rate.append((c.get_rate(currency_conversion[i], 'INR', dt)))
  # print(currency_rate)
print(currency_rate)

# %%
# !pip install easy-exchange-rates
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from easy_exchange_rates import API
api = API()
currency_conversion = list(df1['Currency_code'])
print(currency_conversion)
indian_exchange_rate =[]


for i in range (0,len(currency_conversion)):
  time_series = api.get_exchange_rates(
  base_currency=currency_conversion[i], 
  start_date=str(date.today()), 
  end_date=str(date.today()), 
  targets=["INR"]
)
  data_frame = api.to_dataframe(time_series)
  indian_exchange_rate.append((time_series[str(date.today())]['INR']))
print(data_frame.head(5))
print(indian_exchange_rate)
df1['indian_exchange_rate']=indian_exchange_rate
df1
# Out:
# ['INR', 'AUD', 'BRL', 'CAD', 'IDR', 'NZD', 'PHP', 'QAR', 'SGD', 'ZAR', 'LKR', 'TRY', 'QAR', 'GBP', 'USD']
#                   INR
# 2023-01-10  82.140975
# [1, 56.814636, 15.649242, 61.403809, 0.005276, 52.449122, 1.500239, 22.581795, 61.764347, 4.858181, 0.223837, 4.38036, 22.581795, 100.009291, 82.140975]
#     Country Code         Country Currency_code  indian_exchange_rate
# 0              1           India           INR              1.000000
# 1             14       Australia           AUD             56.814636
# 2             30          Brazil           BRL             15.649242
# 3             37          Canada           CAD             61.403809
# 4             94       Indonesia           IDR              0.005276
# 5            148     New Zealand           NZD             52.449122
# 6            162     Phillipines           PHP              1.500239
# 7            166           Qatar           QAR             22.581795
# ...

# %%
c.convert(100,'INR', 'EUR')
# Out:
# 1.135892499133882

# %%
# !pip install requests
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import requests

def currency_Conversion(initial_currency,target_currency,amount):
  # initial_currency = input("Enter the initial currency: ")
  # target_currency = input("Enter the target currency: ")
  # amount = float(input("Enter the amount: "))

  url = "https://api.apilayer.com/fixer/convert?to=" + target_currency + "&from=" + initial_currency + "&amount=" + str(amount)

  payload = {}
  headers= {
  "apikey": "RJXDDxEBBiBemQohGYhnS9mg6tKBWqUb"
  }

  response = requests.request("GET", url, headers = headers, data = payload)

  status_code = response.status_code

  result = response.json()

  res = str(result["result"])
  return res

# print(currency_Conversion())
