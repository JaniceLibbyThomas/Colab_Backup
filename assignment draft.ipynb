# %%
import re
import os

def Validating_Register():


    a,mail=checking_mailID()
    if(a=="1"):
      a1,password=checking_password()
      print("after returning: ",a1,password)
      if(a1 == '11'):
        appending_in_file(mail,password)
        #moving_to_login()

    #if(a=="2"):
      #Validating_Register()

def appending_in_file(mail,password):

      file1 = open("DB.txt",'a')
      file1.write(mail+" "+password+f"\n")
      file1.close()
      print("*********!!! Sucessfully Registered !!! *********")
      #moving_to_login()

def checking_mailID():
  a=""
  mail = input("Please enter mail ID: ")
  file1 = open("DB.txt",'r')
  temp = (file1.read())
  val = ""
  val1=True
  if(mail in temp):
    pattern_mail1 ='^[a-z0-9]+[\._]?[ a-z0-9]+[@]\w+[. ]\w{2,3}$'
    res1 = re.findall(pattern_mail1,mail)
    if(len(res1)!=0):
      if(res1[-1]==mail):
        a="1"
        val1=False
        print("Mail ID is already registered, Try Login!!!")
        #Login()
    else:
      val1=True
  if(val1==True):
    if(mail[0].isalpha() == True ):  
      pattern_mail ='^[a-z0-9]+[\._]?[ a-z0-9]+[@]\w+[. ]\w{2,3}$'
      res = re.findall(pattern_mail,mail)
      val = len(str(res))-4
      print("value of val and len(mail): ",val,len(mail))
    if(val == len(mail)):
      print("*************************************************")
      a = "1"
      return a,mail
    else:
      print("Mail ID you have entered is Invalid,try again with valid mail ID...")
      #a ="2"
      checking_mailID()
  

def checking_password():
  a1=""
  password = input("Please enter Password: ")
  if re.fullmatch(r'[A-Za-z0-9@#$%^&!*+=]{5,16}', password):
    print("*************************************************")
    a1 = "11"
    print("before return:",a1,password)
    return a1,password
  else:
    print('''***********!!!__Invalid password__!!!**********
Note: Must have minimum one special character, one digit, one uppercase, one lowercase character,5 < password length > 16               
Please try again !!! ''')
    checking_password()

# %%
def checking_mailID1():
  a=""
  mail = input("Please enter mail ID: ")
  file1 = open("DB.txt",'r')
  temp = (file1.read())
  val = ""
  val1=True
  lst=[]
  if(mail in temp):
    pattern_mail1 ='^[a-z0-9]+[\._]?[ a-z0-9]+[@]\w+[. ]\w{2,3}$'
    res1 = re.findall(pattern_mail1,mail)
    if(len(res1)!=0):
      if(res1[-1]==mail):
        a="1"
        val1=False
        print("Mail ID is already registered, Try Login!!!")
        #Login()
    else:
      val1=True
  if(val1==True):
    if(mail[0].isalpha() == True ):  
      pattern_mail ='^[a-z0-9]+[\._]?[ a-z0-9]+[@]\w+[. ]\w{2,3}$'
      res = re.findall(pattern_mail,mail)
      val = len(str(res))-4
      print("value of val and len(mail): ",val,len(mail))
    if(val == len(mail)):
      print("*************************************************")
      a = "1"
      lst.append(a)
      lst.append(mail)
      print("before return:",lst)
      return lst     
      
    else:
      print("Mail ID you have entered is Invalid,try again with valid mail ID...")
      #a ="2"
      return checking_mailID1()

# %%
import re
import os

def Validating_Register():


    l=checking_mailID1()
    print(l)
    a=l[0]
    mail=l[1]
    if(a=="1"):
      l1=checking_password()
      a1=l1[0]
      password=l1[1]
      print("after returning: ",a1,password)
      if(a1 == '11'):
        appending_in_file(mail,password)
        #moving_to_login()

    #if(a=="2"):
      #Validating_Register()

def appending_in_file(mail,password):

      file1 = open("DB.txt",'a')
      file1.write(mail+" "+password+f"\n")
      file1.close()
      print("*********!!! Sucessfully Registered !!! *********")
      #moving_to_login()

# %%
def checking_password():
  a1=""
  password = input("Please enter Password: ")
  reg = "^(?=.*[a-z])(?=.*[A-Z])(?=.*\d)(?=.*[@$!%*#?&])[A-Za-z\d@$!#%*?&]{5,16}$"
  lst=[]
# compiling regex
  pat = re.compile(reg)
  
# searching regex 
  mat = re.search(pat, password)
  
# validating conditions
  if mat:
    print("*************************************************")
    a1 = "11"
    lst.append(a1)
    lst.append(password)
    return lst
  else:
    print('''***********!!!__Invalid password__!!!**********
Note: Must have minimum one special character, one digit, one uppercase, one lowercase character,5 < password length > 16               
Please try again !!! ''')
    return checking_password()

# %%
checking_password1()
# Out:
# Please enter Password: jsdhs
# ***********!!!__Invalid password__!!!**********
# Note: Must have minimum one special character, one digit, one uppercase, one lowercase character,5 < password length > 16
# Please try again !!!
# Please enter Password: Asd12
# ***********!!!__Invalid password__!!!**********
# Note: Must have minimum one special character, one digit, one uppercase, one lowercase character,5 < password length > 16
# Please try again !!!
# Please enter Password: Ads@344443
# *************************************************
# before return: 11 Ads@344443

# %%
checking_mailID1()
# Out:
# Please enter mail ID: jhdsjdh
# value of val and len(mail):  -2 7
# Mail ID you have entered is Invalid,try again with valid mail ID...
# Please enter mail ID: abrahm@df.in
# value of val and len(mail):  12 12
# *************************************************

# %%
print('''*************************************************
            # !!! WELCOME !!!
Select from the options listed below:            
1. Register
2. Login
3. Exit
*************************************************''')
print("Please enter your option as 1 / 2 / 3: ",end="")
option= int(input())
file1 = open("DB.txt", "w")

if(option == 1):
  Validating_Register1()
  print("*************************************************")
elif(option == 2):
  Login()
  print("*************************************************")
elif(option == 3):
  print("Exiting process.....")

file1.close()
# Out:
# *************************************************
#             !!! WELCOME !!!
# Select from the options listed below:
# 1. Register
# 2. Login
# 3. Exit
# *************************************************
# Please enter your option as 1 / 2 / 3: 1
# Please enter mail ID: sdskjds
# value of val and len(mail):  -2 7
# Mail ID you have entered is Invalid,try again with valid mail ID...
# Please enter mail ID: kaskjs
# value of val and len(mail):  -2 6
# Mail ID you have entered is Invalid,try again with valid mail ID...
# Please enter mail ID: hgsn.gm.in
# value of val and len(mail):  -2 10
# Mail ID you have entered is Invalid,try again with valid mail ID...
# Please enter mail ID: agsfa@gm.in
# value of val and len(mail):  11 11
# *************************************************
# before return: ['1', 'agsfa@gm.in']
# ['1', 'agsfa@gm.in']
# Please enter Password: jsdhasjhd
# ***********!!!__Invalid password__!!!**********
# Note: Must have minimum one special character, one digit, one uppercase, one lowercase character,5 < password length > 16
# Please try again !!!
# Please enter Password: Jan123
# ***********!!!__Invalid password__!!!**********
# Note: Must have minimum one special character, one digit, one uppercase, one lowercase character,5 < password length > 16
# Please try again !!!
# Please enter Password: Pa##123
# *************************************************
# after returning:  11 Pa##123
# *********!!! Sucessfully Registered !!! *********
# *************************************************

# %%
def mail_id_existing():
  print("entering mailid exist check")
  val="jane@gmail.com"
  file = open("DB.txt",'r')
  s=(file.read())
  file.close()
  s2=str(str(s.split("\n")).split(" "))
  result=0
  s3=s2.replace("[","").replace("]","").replace("'","").replace('"',"").replace(",,",",").split(",")
  for i in range(0,len(s3)):
    print("value of s3 adn val: ",s3[i] ,val)
    if(s3[i]==val):
      result=1

  print("result:",result)
  if(result==1):
    return 1
  else:
    return 0


def Login():
  mail = input("Please enter Registered mail ID: ")
  password = input("Please enter Registered Password: ")
  file1 =open("DB.txt",'a')
  file1 = open("DB.txt",'r')
  temp = (file1.read())
  check_pass= mail+" "+password
  c=0
  res=mail_id_existing()
  print("value of res: ",res)
  if(res==1):
    if(check_pass in temp):
      print("***********!!!! Login Sucessful !!!!*************")
    else:
      print('''*********!!!! Incorrect Password !!!!**********
Would like to select 
1. Forget password 
2. Reset password
3. Exit ''')
      global user_no
      user_no=input()
      if(user_no=='1'):
        #forget_password(mail,temp) 
        pass
      elif(user_no=='2'):
        #deleting_existing_entry(mail)
        #updating_new_pass(mail)
        pass
      elif(user_no=='3'):
        print("Exiting process....")
        pass
      else:
        print("Invalid entry try agin later !!!")

  else:
    ip= input('''Mail is not registered !!,
Would you like to 
1. login again 
2. Register new account''')
    if(ip==1):
      pass
      #moving_to_login()
    else:
      pass
      #moving_to_reg()
