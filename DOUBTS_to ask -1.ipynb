# %%
#@title DOUBT1- WORKS FINE NOW

'''Given a number N and an array of N strings, find the lexicographically smallest string.
Input Size : N <= 1000
Sample Testcase :
INPUT
3
code
learn
practice
OUTPUT
code'''

n= int(input())
s1=[]
p_v=''
p_l=1000
for i in range (0,n):
  s= input()
  s1.append(s)
  current_len = len(s1[i])
  current_value = s1[i]
  if(p_l > current_len):
    p_l= current_len
    p_v= current_value
  else:
    pass
print(p_v)
# Out:
# 3
# CODE
# PRACTICE
# NODE
# CODE

# %%
'''A number is given as input(as string). Find the maximum length of substring alternating digits of odd and even.
Input Size : N <= 10000000000
Sample Testcase :
INPUT
4123
OUTPUT
4'''

#String - 93 understanding
